# %% [markdown]
# # Checking and Scaling Data

# %% [markdown]
# ## Script Contents:
# ### 1. Importing Libraries
# ### 2. Scaling

# %% [markdown]
# ## 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.preprocessing import StandardScaler

# assign path
path = r'C:\Users\X1\Climate Wins Analysis'

# %%
# import climate dataset

df = pd.read_csv(os.path.join(path,'Data Sets','Dataset-weather-prediction-dataset-processed.csv'))

# %%
# Display all columns

pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0  19600101      1                  7               2.1            0.85
# 1  19600102      1                  6               2.1            0.84
# 2  19600103      1                  8               2.1            0.90
# 3  19600104      1                  3               2.1            0.92
# 4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  BASEL_sunshine  BASEL_temp_mean  BASEL_temp_min  \
# 0                 0             0.7              6.5             0.8
# ...

# %%
df.reset_index(inplace=True)
df.rename(columns={'index':'id'}, inplace=True)
df.head()
# Out:
#    id      DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0   0  19600101      1                  7               2.1            0.85
# 1   1  19600102      1                  6               2.1            0.84
# 2   2  19600103      1                  8               2.1            0.90
# 3   3  19600104      1                  3               2.1            0.92
# 4   4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  BASEL_sunshine  BASEL_temp_mean  BASEL_temp_min  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22950 entries, 0 to 22949
# Columns: 171 entries, id to VALENTIA_temp_max
# dtypes: float64(145), int64(26)
# memory usage: 29.9 MB

# %% [markdown]
# ### 1.1 Check for missing values

# %%
df.isnull().sum()
# Out:
# id                     0
# DATE                   0
# MONTH                  0
# BASEL_cloud_cover      0
# BASEL_wind_speed       0
#                       ..
# VALENTIA_snow_depth    0
# VALENTIA_sunshine      0
# VALENTIA_temp_mean     0
# VALENTIA_temp_min      0
# VALENTIA_temp_max      0
# Length: 171, dtype: int64

# %%
df.shape
# Out:
# (22950, 171)

# %%
# Remove missing values

df.dropna(inplace=True)

# %%
df.shape
# Out:
# (22950, 171)

# %%
# No missing values

# %% [markdown]
# ## 2. Scaling

# %%
# Create scaler object using StandardScaler from sklearn.preprocessing
# StandardScaler assumes data is normally distributed and scales with a distribution
# Around 0 and standard deviation of 1. Scaling happens independently with each variable.

scaler = StandardScaler()

# %%
# First separate the date column since we do not want this scaled

dates = df['DATE']
df = df.drop(columns=['DATE'])

# %%
# Create new df with scaled data

df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
# Combine date column with df_scaled

df_scaled['DATE'] = dates

# Combine date column with original df

df['DATE'] = dates

df_scaled.head()
# Out:
#          id     MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0 -1.731975 -1.599964           0.660514          -0.02793        0.826097
# 1 -1.731824 -1.599964           0.244897          -0.02793        0.735760
# 2 -1.731673 -1.599964           1.076130          -0.02793        1.277781
# 3 -1.731523 -1.599964          -1.001953          -0.02793        1.458455
# 4 -1.731372 -1.599964           0.244897          -0.02793        1.729466
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0       -0.001949               -1.101066            -0.265148
# 1       -0.001949               -1.058108             1.658760
# 2       -0.001949               -1.251420             0.155707
# 3       -0.001949               -0.821838            -0.445514
# 4       -0.001949               -0.746661            -0.164944
#
#    BASEL_snow_depth  BASEL_sunshine  BASEL_temp_mean  BASEL_temp_min  \
# ...

# %%
# Compare the original vs. scaled data

df.head()
# Out:
#    id  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0   0      1                  7               2.1            0.85
# 1   1      1                  6               2.1            0.84
# 2   2      1                  8               2.1            0.90
# 3   3      1                  3               2.1            0.92
# 4   4      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  BASEL_sunshine  BASEL_temp_mean  BASEL_temp_min  \
# 0                 0             0.7              6.5             0.8
# ...

# %%
# Export dataframe as .pkl

df_scaled.to_pickle(os.path.join(path,'Data Sets','climate_scaled.pkl'))

# %%
# Export dataframe as .csv

df_scaled.to_csv(os.path.join(path,'Data Sets','climate_scaled.csv'))
